# %% [markdown]
# 1. 환경 준비

# %%
import os, re
import random, math
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings(action='ignore')

# %%
# 데이터 로드할 때 빠르게 로드할 수 있도록하는 설정 변수
AUTOTUNE = tf.data.experimental.AUTOTUNE
# X-RAY 이미지 사이즈 변수
IMAGE_SIZE = [180, 180]

# 데이터 경로 변수
ROOT_PATH = os.path.join(os.getenv('HOME'), 'aiffel')
TRAIN_PATH = ROOT_PATH + '/chest_xray/data/train/*/*' # *은 모든 디렉토리와 파일을 의미합니다.
VAL_PATH = ROOT_PATH + '/chest_xray/data/val/*/*'
TEST_PATH = ROOT_PATH + '/chest_xray/data/test/*/*'

# 프로젝트를 진행할 때 아래 두 변수를 변경해보세요
BATCH_SIZE = 32
EPOCHS = 25

print(ROOT_PATH)
# Out:
# /aiffel/aiffel

# %% [markdown]
# 2. 데이터 준비

# %%
train_filenames = tf.io.gfile.glob(TRAIN_PATH)
test_filenames = tf.io.gfile.glob(TEST_PATH)
val_filenames = tf.io.gfile.glob(VAL_PATH)

print(len(train_filenames))
print(len(test_filenames))
print(len(val_filenames))
# Out:
# 5216
# 624
# 16

# %%
# train 데이터와 validation 데이터를 모두 filenames에 담습니다
filenames = tf.io.gfile.glob(TRAIN_PATH)
filenames.extend(tf.io.gfile.glob(VAL_PATH))

# 모아진 filenames를 8:2로 나눕니다
train_size = math.floor(len(filenames)*0.8)
random.seed(8)
random.shuffle(filenames)
train_filenames = filenames[:train_size]
val_filenames = filenames[train_size:]

print(len(train_filenames))
print(len(val_filenames))
# Out:
# 4185
# 1047

# %%
print(f'Normal image path\n{filenames[0]}')
print(f'Pneumonia image path\n{filenames[2000]}')
# Out:
# Normal image path
# /aiffel/aiffel/chest_xray/data/train/NORMAL/NORMAL2-IM-1317-0001.jpeg
# Pneumonia image path
# /aiffel/aiffel/chest_xray/data/train/PNEUMONIA/person299_bacteria_1418.jpeg

# %%
COUNT_NORMAL = len([filename for filename in train_filenames if "NORMAL" in filename])
print(f"Normal images count in training set: {COUNT_NORMAL}")


COUNT_PNEUMONIA = len([filename for filename in train_filenames if "PNEUMONIA" in filename])
print(f"Pneumonia images count in training set: {COUNT_PNEUMONIA}")
# Out:
# Normal images count in training set: 1070
# Pneumonia images count in training set: 3115

# %%
train_list_ds = tf.data.Dataset.from_tensor_slices(train_filenames)
val_list_ds = tf.data.Dataset.from_tensor_slices(val_filenames)

# %%
TRAIN_IMG_COUNT = tf.data.experimental.cardinality(train_list_ds).numpy()
print(f"Training images count: {TRAIN_IMG_COUNT}")

VAL_IMG_COUNT = tf.data.experimental.cardinality(val_list_ds).numpy()
print(f"Validating images count: {VAL_IMG_COUNT}")
# Out:
# Training images count: 4185
# Validating images count: 1047

# %%
# 파일 경로의 끝에서 두번째 부분을 확인하면 양성과 음성을 구분할 수 있습니다
def get_label(file_path):
    parts = tf.strings.split(file_path, os.path.sep)
    return parts[-2] == "PNEUMONIA"   # 폐렴이면 양성(True), 노말이면 음성(False)

# %%
# 이미지를 알맞은 형식으로 바꿉니다.
def decode_img(img):
    img = tf.image.decode_jpeg(img, channels=3) # 이미지를 uint8 tensor로 수정
    img = tf.image.convert_image_dtype(img, tf.float32) # float32 타입으로 수정
    img = tf.image.resize(img, IMAGE_SIZE) # 이미지 사이즈를 IMAGE_SIZE로 수정
    return img

# 이미지 파일의 경로를 입력하면 이미지와 라벨을 읽어옵니다.
def process_path(file_path):
    label = get_label(file_path) # 라벨 검출
    img = tf.io.read_file(file_path) # 이미지 읽기
    img = decode_img(img) # 이미지를 알맞은 형식으로 수정
    return img, label

# %%
train_ds = train_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
val_ds = val_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)

# %%
for image, label in train_ds.take(1):
    print("Image shape: ", image.numpy().shape)
    print("Label: ", label.numpy())
# Out:
# Image shape:  (180, 180, 3)
# Label:  False

# %%
test_list_ds = tf.data.Dataset.list_files(TEST_PATH)
TEST_IMAGE_COUNT = tf.data.experimental.cardinality(test_list_ds).numpy()
test_ds = test_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
test_ds = test_ds.batch(BATCH_SIZE)

print(TEST_IMAGE_COUNT)
# Out:
# 624

# %%
def prepare_for_training(ds, shuffle_buffer_size=1000):
    ds = ds.shuffle(buffer_size=shuffle_buffer_size)
    ds = ds.repeat()
    ds = ds.batch(BATCH_SIZE)
    ds = ds.prefetch(buffer_size=AUTOTUNE)
    return ds

train_ds = prepare_for_training(train_ds)
val_ds = prepare_for_training(val_ds)

# %% [markdown]
# 3. 이미지 시각화

# %%
# 이미지 배치를 입력하면 여러장의 이미지를 보여줍니다.
def show_batch(image_batch, label_batch):
    plt.figure(figsize=(10,10))
    for n in range(BATCH_SIZE):
        ax = plt.subplot(4,math.ceil(BATCH_SIZE/4),n+1)
        plt.imshow(image_batch[n])
        if label_batch[n]:
            plt.title("PNEUMONIA")
        else:
            plt.title("NORMAL")
        plt.axis("off")


image_batch, label_batch = next(iter(train_ds))
show_batch(image_batch.numpy(), label_batch.numpy())

# %% [markdown]
# 4. CNN 모델링

# %%
def conv_block(filters):
    block = tf.keras.Sequential([
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.MaxPool2D()
    ])
    
    return block

# %%
def dense_block(units, dropout_rate):
    block = tf.keras.Sequential([
        tf.keras.layers.Dense(units, activation='relu'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(dropout_rate)
    ])
    
    return block

# %%
def build_model():
    model = tf.keras.Sequential([
        tf.keras.Input(shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)),
        
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.MaxPool2D(),
        
        conv_block(32),
        conv_block(64),
        
        conv_block(128),
        tf.keras.layers.Dropout(0.2),
        
        conv_block(256),
        tf.keras.layers.Dropout(0.2),
        
        tf.keras.layers.Flatten(),
        dense_block(512, 0.7),
        dense_block(128, 0.5),
        dense_block(64, 0.3),
        
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])
    
    return model

# %% [markdown]
# 5. 데이터 불균형 처리

# %%
weight_for_0 = (1 / COUNT_NORMAL)*(TRAIN_IMG_COUNT)/2.0 
weight_for_1 = (1 / COUNT_PNEUMONIA)*(TRAIN_IMG_COUNT)/2.0

class_weight = {0: weight_for_0, 1: weight_for_1}

print('Weight for NORMAL: {:.2f}'.format(weight_for_0))
print('Weight for PNEUMONIA: {:.2f}'.format(weight_for_1))
# Out:
# Weight for NORMAL: 1.96
# Weight for PNEUMONIA: 0.67

# %% [markdown]
# 6. 모델 훈련

# %%
with tf.device('/GPU:0'):
    model = build_model()

    METRICS = [
        'accuracy',
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall')
    ]
    
    model.compile(
        optimizer='adam',
        loss='binary_crossentropy',
        metrics=METRICS
    )

# %%
with tf.device('/GPU:0'):
    history = model.fit(
        train_ds,
        steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=val_ds,
        validation_steps=VAL_IMG_COUNT // BATCH_SIZE,
        class_weight=class_weight,
    )
# Out:
# Epoch 1/25
# 130/130 [==============================] - 84s 368ms/step - loss: 0.4462 - accuracy: 0.7692 - precision: 0.9388 - recall: 0.7380 - val_loss: 0.5951 - val_accuracy: 0.7344 - val_precision: 0.7344 - val_recall: 1.0000
# Epoch 2/25
# 130/130 [==============================] - 48s 372ms/step - loss: 0.2110 - accuracy: 0.9202 - precision: 0.9772 - recall: 0.9140 - val_loss: 0.7540 - val_accuracy: 0.7373 - val_precision: 0.7373 - val_recall: 1.0000
# Epoch 3/25
# 130/130 [==============================] - 49s 375ms/step - loss: 0.1730 - accuracy: 0.9373 - precision: 0.9787 - recall: 0.9361 - val_loss: 0.9590 - val_accuracy: 0.7334 - val_precision: 0.7334 - val_recall: 1.0000
# Epoch 4/25
# 130/130 [==============================] - 50s 385ms/step - loss: 0.1612 - accuracy: 0.9423 - precision: 0.9773 - recall: 0.9444 - val_loss: 1.3540 - val_accuracy: 0.7305 - val_precision: 0.7305 - val_recall: 1.0000
# Epoch 5/25
# 130/130 [==============================] - 54s 416ms/step - loss: 0.1445 - accuracy: 0.9505 - precision: 0.9836 - recall: 0.9493 - val_loss: 1.1521 - val_accuracy: 0.7314 - val_precision: 0.7314 - val_recall: 1.0000
# Epoch 6/25
# 130/130 [==============================] - 46s 358ms/step - loss: 0.1226 - accuracy: 0.9522 - precision: 0.9843 - recall: 0.9510 - val_loss: 0.0980 - val_accuracy: 0.9629 - val_precision: 0.9554 - val_recall: 0.9960
# Epoch 7/25
# 130/130 [==============================] - 46s 355ms/step - loss: 0.1149 - accuracy: 0.9563 - precision: 0.9850 - recall: 0.9558 - val_loss: 0.1948 - val_accuracy: 0.9131 - val_precision: 0.8940 - val_recall: 1.0000
# Epoch 8/25
# 130/130 [==============================] - 47s 364ms/step - loss: 0.1074 - accuracy: 0.9613 - precision: 0.9883 - recall: 0.9592 - val_loss: 0.1018 - val_accuracy: 0.9619 - val_precision: 0.9958 - val_recall: 0.9522
# Epoch 9/25
# 130/130 [==============================] - 46s 354ms/step - loss: 0.1004 - accuracy: 0.9647 - precision: 0.9871 - recall: 0.9652 - val_loss: 0.8521 - val_accuracy: 0.7461 - val_precision: 0.7433 - val_recall: 1.0000
# Epoch 10/25
# 130/130 [==============================] - 47s 360ms/step - loss: 0.1004 - accuracy: 0.9627 - precision: 0.9878 - recall: 0.9620 - val_loss: 0.0903 - val_accuracy: 0.9678 - val_precision: 0.9813 - val_recall: 0.9748
# Epoch 11/25
# 130/130 [==============================] - 46s 354ms/step - loss: 0.0943 - accuracy: 0.9654 - precision: 0.9907 - recall: 0.9624 - val_loss: 0.6151 - val_accuracy: 0.8271 - val_precision: 1.0000 - val_recall: 0.7646
# Epoch 12/25
# 130/130 [==============================] - 46s 354ms/step - loss: 0.0714 - accuracy: 0.9721 - precision: 0.9934 - recall: 0.9690 - val_loss: 0.0766 - val_accuracy: 0.9736 - val_precision: 0.9701 - val_recall: 0.9947
# Epoch 13/25
# 130/130 [==============================] - 46s 357ms/step - loss: 0.0650 - accuracy: 0.9791 - precision: 0.9938 - recall: 0.9780 - val_loss: 0.1105 - val_accuracy: 0.9707 - val_precision: 0.9891 - val_recall: 0.9707
# Epoch 14/25
# 130/130 [==============================] - 47s 362ms/step - loss: 0.0958 - accuracy: 0.9678 - precision: 0.9897 - recall: 0.9667 - val_loss: 0.2980 - val_accuracy: 0.9170 - val_precision: 1.0000 - val_recall: 0.8868
# Epoch 15/25
# 130/130 [==============================] - 46s 356ms/step - loss: 0.0685 - accuracy: 0.9743 - precision: 0.9934 - recall: 0.9719 - val_loss: 0.0821 - val_accuracy: 0.9766 - val_precision: 0.9946 - val_recall: 0.9733
# Epoch 16/25
# 130/130 [==============================] - 46s 358ms/step - loss: 0.0690 - accuracy: 0.9760 - precision: 0.9918 - recall: 0.9759 - val_loss: 0.1234 - val_accuracy: 0.9590 - val_precision: 1.0000 - val_recall: 0.9442
# Epoch 17/25
# 130/130 [==============================] - 46s 356ms/step - loss: 0.0593 - accuracy: 0.9784 - precision: 0.9934 - recall: 0.9773 - val_loss: 0.0927 - val_accuracy: 0.9697 - val_precision: 0.9972 - val_recall: 0.9614
# Epoch 18/25
# 130/130 [==============================] - 46s 358ms/step - loss: 0.0570 - accuracy: 0.9822 - precision: 0.9948 - recall: 0.9813 - val_loss: 0.0927 - val_accuracy: 0.9707 - val_precision: 0.9641 - val_recall: 0.9973
# Epoch 19/25
# 130/130 [==============================] - 46s 359ms/step - loss: 0.0521 - accuracy: 0.9791 - precision: 0.9932 - recall: 0.9788 - val_loss: 0.1275 - val_accuracy: 0.9600 - val_precision: 0.9972 - val_recall: 0.9478
# Epoch 20/25
# 130/130 [==============================] - 46s 358ms/step - loss: 0.0615 - accuracy: 0.9788 - precision: 0.9941 - recall: 0.9774 - val_loss: 0.1012 - val_accuracy: 0.9648 - val_precision: 0.9986 - val_recall: 0.9535
# Epoch 21/25
# 130/130 [==============================] - 46s 357ms/step - loss: 0.0614 - accuracy: 0.9779 - precision: 0.9944 - recall: 0.9758 - val_loss: 0.1098 - val_accuracy: 0.9629 - val_precision: 0.9945 - val_recall: 0.9547
# Epoch 22/25
# 130/130 [==============================] - 46s 355ms/step - loss: 0.0643 - accuracy: 0.9784 - precision: 0.9928 - recall: 0.9780 - val_loss: 0.2765 - val_accuracy: 0.9189 - val_precision: 1.0000 - val_recall: 0.8892
# Epoch 23/25
# 130/130 [==============================] - 47s 360ms/step - loss: 0.0686 - accuracy: 0.9779 - precision: 0.9925 - recall: 0.9777 - val_loss: 0.3816 - val_accuracy: 0.8779 - val_precision: 1.0000 - val_recall: 0.8338
# Epoch 24/25
# 130/130 [==============================] - 46s 352ms/step - loss: 0.0524 - accuracy: 0.9820 - precision: 0.9960 - recall: 0.9795 - val_loss: 0.0693 - val_accuracy: 0.9766 - val_precision: 0.9959 - val_recall: 0.9722
# Epoch 25/25
# 130/130 [==============================] - 46s 358ms/step - loss: 0.0454 - accuracy: 0.9865 - precision: 0.9961 - recall: 0.9859 - val_loss: 1.6434 - val_accuracy: 0.6279 - val_precision: 1.0000 - val_recall: 0.4900

# %% [markdown]
# 7. 결과 확인

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['precision', 'recall', 'accuracy', 'loss']):
    ax[i].plot(history.history[met])
    ax[i].plot(history.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %%
loss, accuracy, precision, recall = model.evaluate(test_ds)
print(f'Loss: {loss},\nAccuracy: {accuracy},\nPrecision: {precision},\nRecall: {recall}')
# Out:
# 20/20 [==============================] - 6s 297ms/step - loss: 0.9794 - accuracy: 0.7404 - precision: 0.9351 - recall: 0.6282
# Loss: 0.9794219732284546,
# Accuracy: 0.7403846383094788,
# Precision: 0.9351145029067993,
# Recall: 0.6282051205635071

# %% [markdown]
# 회고
#
# * 노드 코드를 따라가는 것은 맞으나 약간의 이해는 증진된 모양.
# * 회전이나 반전 같이 노이즈를 발생시키는 방식의 데이터 증강은 의료자료에 적합하지 않다고 생각해 피했다.
# * 적절한 배치 사이즈 찾는데에 집중. 처음에는 https://goodtogreate.tistory.com/entry/Batch-%ED%81%AC%EA%B8%B0%EC%9D%98-%EA%B2%B0%EC%A0%95-%EB%B0%A9%EB%B2%95 를 참고해 64로 실험했으나 별로 좋지 않아(loss: 0.8915 - accuracy: 0.8301 - precision: 0.7983 - recall: 0.9744)32로 줄여서 실험했는데 결과가 더 좋지 않았다.
# * 배치 사이즈는 32의 배수로 많이 쓰는 듯 하다. 그러는 게 좋다는 말은 많은데 이유는 분명하게 찾지 못했다.
